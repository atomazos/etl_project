# %%
import pandas as pd
from sqlalchemy import create_engine
import io
import requests

# %%
gameinfo_09 = pd.read_csv("https://raw.githubusercontent.com/ryurko/nflscrapR-data/master/games_data/regular_season/reg_games_2009.csv", sep = ',', header = 0)

# %%
gameinfo_09
# Out:
#     type     game_id home_team away_team  week  season state_of_game  \
# 0    reg  2009091000       PIT       TEN     1    2009          POST
# 1    reg  2009091304       CLE       MIN     1    2009          POST
# 2    reg  2009091307        NO       DET     1    2009          POST
# 3    reg  2009091308        TB       DAL     1    2009          POST
# 4    reg  2009091305       HOU       NYJ     1    2009          POST
# ..   ...         ...       ...       ...   ...     ...           ...
# 251  reg  2010010314        SD       WAS    17    2009          POST
# 252  reg  2010010313       OAK       BAL    17    2009          POST
# 253  reg  2010010303       DAL       PHI    17    2009          POST
# 254  reg  2010010315       SEA       TEN    17    2009          POST
# 255  reg  2010010308       NYJ       CIN    17    2009          POST
#
#                                               game_url  home_score  away_score
# ...

# %%
gameinfo_10 = pd.read_csv("https://raw.githubusercontent.com/ryurko/nflscrapR-data/master/games_data/regular_season/reg_games_2010.csv", sep = ',', header = 0)
gameinfo_10
# Out:
#     type     game_id home_team away_team  week  season state_of_game  \
# 0    reg  2010090900        NO       MIN     1    2010          POST
# 1    reg  2010091200        TB       CLE     1    2010          POST
# 2    reg  2010091209       PIT       ATL     1    2010          POST
# 3    reg  2010091207       CHI       DET     1    2010          POST
# 4    reg  2010091206       NYG       CAR     1    2010          POST
# ..   ...         ...       ...       ...   ...     ...           ...
# 251  reg  2011010204       HOU       JAC    17    2010          POST
# 252  reg  2011010207       PHI       DAL    17    2010          POST
# 253  reg  2011010213       DEN        SD    17    2010          POST
# 254  reg  2011010214        SF       ARI    17    2010          POST
# 255  reg  2011010215       SEA       STL    17    2010          POST
#
#                                               game_url  home_score  away_score
# ...

# %%
gameinfo_11 = pd.read_csv("https://raw.githubusercontent.com/ryurko/nflscrapR-data/master/games_data/regular_season/reg_games_2011.csv", sep = ',', header = 0)
gameinfo_11
# Out:
#     type     game_id home_team away_team  week  season state_of_game  \
# 0    reg  2011090800        GB        NO     1    2011          POST
# 1    reg  2011091100       BAL       PIT     1    2011          POST
# 2    reg  2011091107       STL       PHI     1    2011          POST
# 3    reg  2011091106        TB       DET     1    2011          POST
# 4    reg  2011091105       CHI       ATL     1    2011          POST
# ..   ...         ...       ...       ...   ...     ...           ...
# 251  reg  2012010113       DEN        KC    17    2011          POST
# 252  reg  2012010103       CLE       PIT    17    2011          POST
# 253  reg  2012010102       CIN       BAL    17    2011          POST
# 254  reg  2012010115       ARI       SEA    17    2011          POST
# 255  reg  2012010106       NYG       DAL    17    2011          POST
#
#                                               game_url  home_score  away_score
# ...

# %%
gameinfo_12 = pd.read_csv("https://raw.githubusercontent.com/ryurko/nflscrapR-data/master/games_data/regular_season/reg_games_2012.csv", sep = ',', header = 0)
gameinfo_12
# Out:
#     type     game_id home_team away_team  week  season state_of_game  \
# 0    reg  2012090500       NYG       DAL     1    2012          POST
# 1    reg  2012090900       CHI       IND     1    2012          POST
# 2    reg  2012090908        KC       ATL     1    2012          POST
# 3    reg  2012090907       CLE       PHI     1    2012          POST
# 4    reg  2012090906        NO       WAS     1    2012          POST
# ..   ...         ...       ...       ...   ...     ...           ...
# 251  reg  2012123001        NE       MIA    17    2012          POST
# 252  reg  2012123012       DEN        KC    17    2012          POST
# 253  reg  2012123013        SD       OAK    17    2012          POST
# 254  reg  2012123014        SF       ARI    17    2012          POST
# 255  reg  2012123007       WAS       DAL    17    2012          POST
#
#                                               game_url  home_score  away_score
# ...

# %%
gameinfo_13 = pd.read_csv("https://raw.githubusercontent.com/ryurko/nflscrapR-data/master/games_data/regular_season/reg_games_2013.csv", sep = ',', header = 0)
gameinfo_13
# Out:
#     type     game_id home_team away_team  week  season state_of_game  \
# 0    reg  2013090500       DEN       BAL     1    2013          POST
# 1    reg  2013090800       BUF        NE     1    2013          POST
# 2    reg  2013090809       PIT       TEN     1    2013          POST
# 3    reg  2013090808        NO       ATL     1    2013          POST
# 4    reg  2013090807       NYJ        TB     1    2013          POST
# ..   ...         ...       ...       ...   ...     ...           ...
# 251  reg  2013122901       CHI        GB    17    2013          POST
# 252  reg  2013122912       ARI        SF    17    2013          POST
# 253  reg  2013122913       OAK       DEN    17    2013          POST
# 254  reg  2013122914        SD        KC    17    2013          POST
# 255  reg  2013122903       DAL       PHI    17    2013          POST
#
#                                               game_url  home_score  away_score
# ...

# %%
gameinfo_df = pd.concat([gameinfo_09, gameinfo_10, gameinfo_11, gameinfo_12, gameinfo_13],ignore_index=True).drop_duplicates().reset_index(drop=True)

# %%
gameinfo_df
# Out:
#      type     game_id home_team away_team  week  season state_of_game  \
# 0     reg  2009091000       PIT       TEN     1    2009          POST
# 1     reg  2009091304       CLE       MIN     1    2009          POST
# 2     reg  2009091307        NO       DET     1    2009          POST
# 3     reg  2009091308        TB       DAL     1    2009          POST
# 4     reg  2009091305       HOU       NYJ     1    2009          POST
# ...   ...         ...       ...       ...   ...     ...           ...
# 1275  reg  2013122901       CHI        GB    17    2013          POST
# 1276  reg  2013122912       ARI        SF    17    2013          POST
# 1277  reg  2013122913       OAK       DEN    17    2013          POST
# 1278  reg  2013122914        SD        KC    17    2013          POST
# 1279  reg  2013122903       DAL       PHI    17    2013          POST
#
#                                                game_url  home_score  \
# ...
